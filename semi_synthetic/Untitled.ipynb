# %%
import ast
file_path = 'proposed.txt'
# Load and parse each line
hyps = []
with open(file_path, 'r') as f:
    for line in f:
        if len(line.split(',')) > 2:
            hyps.append(ast.literal_eval(line.strip()))

# %%
hyps
# Out:
# [[1.0, 95, 1, 64, 128, 0.0005, 1e-06, 0.075, 'linear'],
#  [1.0, 95, 1, 32, 128, 0.0005, 1e-05, 0.075, 'linear'],
#  [1.0, 95, 1, 16, 128, 0.0005, 1e-06, 0.075, 'linear']]

# %%
import joblib

X_train = joblib.load('$CWITE_DATA_ROOT/support50_propbin_data/X_train_covariate_low_resource.joblib')
X_val = joblib.load('$CWITE_DATA_ROOT/support50_propbin_data/X_val_covariate_low_resource.joblib')
X_test = joblib.load('$CWITE_DATA_ROOT/support50_propbin_data/X_test_covariate_low_resource.joblib')

# %%
print(X_train.shape[0] + X_val.shape[0] + X_test.shape[0])
# Out:
# 6201

# %%
X_train.shape[1]
# Out:
# 31
